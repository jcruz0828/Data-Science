# %%
import pandas as pd
titanicData = pd.read_csv("titanic_train-Copy1.csv")
titanicData2 = pd.read_csv("titanic_train-Copy1.csv")
titanicData.isna().sum()
titanicData.drop(columns = ['Cabin'], inplace = True)
titanicData['Age'].fillna(titanicData['Age'].mean(), inplace=True)


titanicData.dropna(inplace=True)

titanicData.head(30)

titanicData['Age'].hist()
# Out:
# /var/folders/7f/k112vzxs0qb0hm1r03sgnk5m0000gn/T/ipykernel_60167/1041900831.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanicData['Age'].fillna(titanicData['Age'].mean(), inplace=True)
# <Axes: >

# %%
titanicData2['Age'].hist()
# Out:
# <Axes: >
